# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-64-64156d691fe5> in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from Utils.methods import change_the_sentences

from keras import models, layers
from sklearn import metrics
import numpy as np

class Keras_Model:

    def __init__(self, params):
        '''
        Initializing Keras Model for Sentiment Analysis Task

        Parameters
        __________
        params: dict | Information regarding number of words, max sent.length, embedding dimension
        '''
        self.model = models.Sequential()
        self.model.add(layers.Embedding(params["NB_WORDS"], params['EMB_DIM'], input_length=params['MAX_LEN']))
        self.model.add(layers.Flatten())
        self.model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-63-9cd14eaf24ae> in <module>
#       1 from Utils.methods import change_the_sentences
#       2
# ----> 3 from keras import models, layers
#       4 from sklearn import metrics
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'keras'

# %%
from Evaluation.weat_analysis import *
from Utils.methods import *
from Utils.sets import *

from sklearn.metrics.pairwise import cosine_similarity as cs
from sklearn.decomposition import PCA
from scipy.linalg import null_space as ns
from nltk.corpus import stopwords
from copy import deepcopy as cp
import pickle
import time

class Word_Embedding:

    def __init__(self, filename, dimension=300):
        """
        Word Embedding initialization

        Parameters
        ----------
        filename: String | directory of the .txt Embedding file
        dimension: int | Embedding dimensionality (has to correspond with .txt file)
        """
        self.words = []
        self.vectors = []
        self.word_idx = {}
        self.dimension = dimension
        assert (filename is not None)

        with open(filename+".vocab", "r") as f:
            self.words = [line.strip() for line in f]
        vectors = np.load(filename+".npy")
        self.vectors = (vectors.T/np.linalg.norm(vectors,axis=1)).T
        word_counter = np.shape(self.vectors)[0]
        self.word_ids = {w:i for i,w in enumerate(self.words)}
        
        print(f'Regular embedding successfully read. Shape: {np.shape(self.vectors)}')

    def get_value(self, word):
        '''
        Get vector representation for particular word

        Parameters
        ----------
        word: String | String representation of the word

        Returns
        -------
        vectors: list | Vector representation of the word
        '''
        try:
            return self.vectors[self.get_index_out_of_word(word)]
        except:
            print(f'Word {word} not in the Embedding.')

    def get_word_out_of_index(self, idx):
        '''
        Take word with the corresponding index from dictionary

        Parameters
        ----------
        idx: int | Index of a word

        Returns
        -------
        word: String | String representation of the word
        '''
        return self.vectors[idx]

    def get_index_out_of_word(self, word):
        '''
        Take word with the corresponding index from dictionary

        Parameters
        ----------
        word: String | String representation of the word

        Returns
        -------
        index: int | Index for the given word
        '''
        return self.word_idx[word]

    def normalize_vectors(self):
        '''
        Vector normalization
        '''
        self.vectors /= np.linalg.norm(self.vectors, axis=1)[:, np.newaxis]

    def get_top_k_neighbors(self, word, k):
        '''
        Find top k neighbors for a given word

        Parameters
        ----------
        word: String | Word for which we ought to find closest k words
        k: int | Number of closest neighbors we ought to output

        Returns
        -------
        top_k_words : list | Top k closest words in space
        '''
        v_s = self.vectors / np.linalg.norm(self.vectors, axis=1)[:, np.newaxis]
        query_vector = v_s[self.get_index_out_of_word(word)]
        dots = np.dot(v_s[:, np.newaxis], query_vector)
        result = {self.words[i]: round(float(dot),3) for i, dot in enumerate(dots)}
        return sorted(result.items(), key=lambda x: x[1], reverse=True)[1:(k + 1)]

    def get_center_vector(self, def_sets):
        '''
        Paper reference: https://www.aclweb.org/anthology/N19-1062/
        Code source: https://github.com/TManzini/DebiasMulticlassWordEmbedding
        '''
        means = {}
        for k, v in def_sets.items():
            wSet = []
            for w in v:
                try:
                    wSet.append(self.get_value(w))
                except KeyError as e:
                    pass
            set_vectors = np.array(wSet)
            means[k] = np.mean(set_vectors, axis=0)
            
        # calculate vectors to perform PCA
        matrix = []
        for k, v in def_sets.items():
            wSet = []
            for w in v:
                try:
                    wSet.append(self.get_value(w))
                except KeyError as e:
                    pass
            set_vectors = np.array(wSet)
            diffs = set_vectors - means[k]
            matrix.append(diffs)

        matrix = np.concatenate(matrix)

        pca = PCA(n_components=1)
        pca.fit(matrix)
        return pca.components_[0]

    def hard_weat(self, bias_levels, bias_combinations, subspace_words, sets, neighbors_threshold=1):
        '''
        HardWEAT Debiasing

        Parameters
        ----------
        bias_levels: dict | Bias levels for each class respectively
        bias_combinations: dict | Classes and respective subclasses to be included in debiasing, by default in following form : {"gender" : ["male_terms", "female_terms"],   "race": ["black_names", "white_names"], "religion" : ["islam_words", "atheism_words", "christianity_words"]}
        subspace_words: set | Words within the default combination dictionary
        sets: dict | Existing attribute and target set of words
        neighbors_threshold: float | Cosine similarity float threshold for equidistancing phase
        '''
        def_vectors, subcategories_vectors, r_cat= {}, {}, 0.0000000000000000001
        temp_sets = cp(sets)
        def_sets = get_hardweat_sets()

        def_vectors = {bias_category: self.get_center_vector(def_sets[bias_category]) for bias_category in bias_combinations}
        centroid = generate_centroid(scale_bias(bias_levels), def_vectors)
        neutral_words = list(set(self.words) -subspace_words)

        start = time.time()
        print(f'Start of neutralization, there is total of {len(neutral_words)} neutral words out of total {len(self.words)} words.')
        neutral_indices = [self.word_idx[word] for word in neutral_words]
        self.vectors[neutral_indices] = neutralize_vectors(self.vectors[neutral_indices,:], centroid)
        self.normalize_vectors()
        end = time.time();
        print(f'Neutralization done in {round(end-start, 3)}s, starting with neighbor thresholding and equidistancing...')

        start = time.time()
        for key_category in def_vectors:

            subcat_keys_within_this_cat = [x for t in list(bias_combinations[key_category].keys()) for x in t]
            vectors_for_equidistancing = {key: np.zeros(self.dimension) for key in subcat_keys_within_this_cat}
            center_vector = neutralize_vectors(def_vectors[key_category], centroid)
            equidistant_def_subcat_vectors_dict = make_vectors_equidistant(center_vector, vectors_for_equidistancing, r_cat)

            for i, key_subcategory in enumerate(subcat_keys_within_this_cat):
                values_okay, values_not_ok_idx, values_not_ok_idx_max = False, 0, 500
                while not values_okay:

                    r_subcat = random.randint(1, 2**16-1)
                    new_vectors = make_vectors_equidistant(equidistant_def_subcat_vectors_dict[key_subcategory], {word: self.get_value(word) for word in temp_sets[key_subcategory]}, r_subcat)

                    found_artifact = False
                    matrix_of_similarities = cs(np.float16(list(new_vectors.values())), np.float16(self.vectors))

                    for ravel_idx, cs_value in enumerate(np.ravel(matrix_of_similarities)):
                        if (cs_value>neighbors_threshold):
                            found_artifact = True
                            values_not_ok_idx+=1
                            if(values_not_ok_idx % 100==0):
                                print(f'{values_not_ok_idx} unsuccessful equdistancing iterations for {key_subcategory}')
                            break

                    if (found_artifact == True and values_not_ok_idx<values_not_ok_idx_max):
                        values_okay = False
                    else:
                        for key in new_vectors:
                            self.vectors[self.get_index_out_of_word(key)] = new_vectors[key]
                        values_okay = True
                        if (values_not_ok_idx>=values_not_ok_idx_max):
                            print(f'Could not perform equidistancing below the requested threshold for {key_subcategory}')

            print(f'Finished with all {key_category} subcategories')

        self.normalize_vectors()
        self.vectors = np.array(self.vectors)
        end = time.time();
        print(f'Equidistancing done in {round(end-start, 3)}s.')

    def soft_weat(self, sets, target_at_dict, bias_combinations, l=1, nullspace_iterations = -1, neighb_count=20):
        '''
        SoftWEAT Debiasing

        Parameters
        ----------
        sets: Existing attribute and target set of words
        target_at_dict: dict | Keys being target/subclass sets and values corresponding attribute sets for debiasing
        bias_combinations: dict | Classes and respective subclasses to be included in debiasing, by default in following form : {"gender" : ["male_terms", "female_terms"],   "race": ["black_names", "white_names"], "religion" : ["islam_words", "atheism_words", "christianity_words"]}
        l: float | Trade-off parameter (1 - Highest level of removal, 0 - lowest)
        nullspace_iterations: int | Number of nullspaces to be included in iterative bias minimization. If -1, all are taken into consideration
        neighb_count: int | Number of neighbors that initial target/subclass lists are expanded on
        '''

        nullspace_dict, neighbors, subclasses, duplicates = {}, {}, [], {} 
        target_words_complete = list(dict.fromkeys([word for class_name in target_at_dict for word in sets[class_name]]))
        substopwords = set(stopwords.words('english')) - set(target_words_complete)
        attribute_sets_complete = set([word for subclass_name in target_at_dict for a_set in target_at_dict[subclass_name]for word in sets[a_set]])

        cs_matrix = cs([self.get_value(word) for word in target_words_complete], self.vectors)
        cs_idx = {word:idx for idx, word in enumerate(target_words_complete)}
        dictionary_categories = {"gender" : ["male_terms", "female_terms"],   "race": ["black_names", "white_names"], "religion" : ["islam_words", "atheism_words", "christianity_words"]}

        #Generating neighbors
        for class_name in dictionary_categories.keys():
            for subclass_name in dictionary_categories[class_name]:

                if subclass_name not in target_at_dict: continue
                
                subclasses.append(subclass_name)
                neighbors[subclass_name] = set(sets[subclass_name])
                for word in sets[subclass_name]:
                    new_words = set([self.words[neighbor_idx] for neighbor_idx in (cs_matrix[cs_idx[word],:].argsort()[-neighb_count:]) if cs([self.vectors[neighbor_idx]], [self.get_value(word)]) > 0.6])
                    new_words -= set([word for class_name, subclasses in dictionary_categories.items() for subcl in subclasses for word in sets[subcl] if subcl!=subclass_name])
                    neighbors[subclass_name] = neighbors[subclass_name].union(new_words)

                    #Identifying duplicates
                    for word in new_words:
                        for subclass in subclasses:
                            if word in neighbors[subclass] and subclass!=subclass_name:
                                if word not in duplicates:
                                    duplicates[word] = set()
                                duplicates[word].add(subclass)
                                duplicates[word].add(subclass_name)
        
        #Removing duplicates
        for word_dup in duplicates:
            word_dup_subclasses = list(duplicates[word_dup])
            cs_subclasses = [cs([np.sum([self.get_value(w) for w in sets[subclass_name]], axis = 0)], [self.get_value(word_dup)]) for subclass_name in word_dup_subclasses]
            for sc in [x for i,x in enumerate(word_dup_subclasses) if i!=np.argmax(cs_subclasses)]:
                neighbors[sc].remove(word_dup)

        for class_name in dictionary_categories.keys():

            #Iterating through target set that might contain bias towards some attribute sets of words 
            for subclass_name in dictionary_categories[class_name]:

                if subclass_name not in target_at_dict.keys(): 
                    continue 

                attribute_set_names = list(target_at_dict[subclass_name]); attribute_set_names.sort()
                all_words_for_subclass = list( neighbors[subclass_name] - attribute_sets_complete - substopwords)
                mean_value = np.mean([self.get_value(word) for word in all_words_for_subclass], axis=0)
                vectors_for_nullspacing = np.array([self.get_wordset_mean(sets[a_set]) for a_set in attribute_set_names])
                null_space = ns(vectors_for_nullspacing)

                bias_levels_per_nullspace = []
                #print(f'Words for subclass {subclass_name} len: {(all_words_for_subclass)}')

                no_of_iterations = np.size(null_space, 1) if nullspace_iterations==-1 else nullspace_iterations
                for k in range(0, no_of_iterations):

                    e = cp(self)
                    nullspace_dict[subclass_name] = null_space[:,k] 
                    T = nullspace_dict[subclass_name] -  mean_value
                    T = make_translation_matrix(T, l)
                    vectors_for_translation = np.vstack([np.transpose([e.get_value(word) for word in all_words_for_subclass]), np.ones((1, len(all_words_for_subclass)))])
                    transformed_points = np.matmul(T, vectors_for_translation)
                    for i, word in enumerate(all_words_for_subclass):  
                        e.vectors[e.get_index_out_of_word(word)] = transformed_points[0:-1,i]
                    _, bias_levels_d, _, _, _ = weat_analysis(e, bias_combinations, sets, steps=1000)
                    bias_levels_per_nullspace.append(bias_levels_d[class_name])
                    del e

                min_nullspace_key = np.argmin(bias_levels_per_nullspace)
                final_t_vector = null_space[:,min_nullspace_key] - mean_value
                T_final = make_translation_matrix(final_t_vector, l)
                vectors_for_translation = np.vstack([np.transpose([self.get_value(word) for word in all_words_for_subclass]), np.ones((1, len(all_words_for_subclass)))])
                transformed_points = np.matmul(T_final, vectors_for_translation)

                for i, word in enumerate(all_words_for_subclass):  
                    self.vectors[self.get_index_out_of_word(word)] = transformed_points[0:-1,i]
                
                print(f'Subclass {subclass_name} finished.')
                
        self.normalize_vectors()

    def get_wordset_mean(self, set_of_words):
        """
        For Embedding and given set of words, find average vector

        Parameters
        ----------
        embedding: Embedding | Word Embedding instance
        set_of_words: list | words which will be averaged based on their vector position

        Returns
        -------
        set_mean: ndarray | Average value of all given word representations
        """
        matrix = [self.get_value(word) for word in set_of_words]
        return np.mean(matrix, axis=0)

    def reduce_dim_version_of_embeddings(self, dimension=3):
        '''
        Reduce dimensionality of embeddings via PCA

        Parameters
        ----------
        dimension: dimensionality to which embeddings will be reduced
        '''
        self.vectors = PCA(n_components=dimension).fit_transform(self.vectors)

    def save_embedding(self, filename, pkl_format=False):
        '''
        Save Embedding in pkl/txt format

        Parameters
        ----------
        filename: String | directory, filename to which output will be generated
        pkl_format: bool | Determining whether embeddings will be saves in .txt or .pkl format
        '''
        if(pkl_format==True):
            print(f'entered pkl method for file: {filename}')
            output = open(f'{filename}.pkl', 'wb')
            pickle.dump(self, output)
            output.close()
        else:
            print(f'entered txt method for file: {filename}')
            with open(filename, 'w') as file:
                for i in range(0, len(self.vectors)):
                    vector_string = f'{self.words[i]} ' + ' '.join([str(np.float16(x)) for x in self.vectors[i]])
                    if (i != len(self.vectors)-1):
                        file.write(f'{vector_string}\n')
                    else:
                        file.write(f'{vector_string}')
                print('Done.')
            file.close()

# %%
def get_sent_analysis_sets():

    """
    Generate structures for Sentiment Analysis task

    Returns
    -------
    dictionary_categories: dict | Bias class as keys and respective subclasses as values
    parameters_dict: dict | Input model information
    target_sets_dict: dict | Dictionary containing existing words for each Word Embedding model within a subclass pair
    """

    dictionary_categories = {"gender": ["male_terms", "female_terms"], "race": ["black_names", "white_names"],
                             "religion": ["islam_words", "atheism_words", "christianity_words"]}

    parameters_dict = \
        {
            "NB_WORDS": 124252,
            "MAX_LEN": 50,
            "NO_PRETR_DIM": 100,
            "EMB_DIM": 300
        }

    target_sets_dict = {
        'black_white':
            {
                'word2vec':
                    {
                        'first_set': ['theo', 'jerome', 'leroy', 'lamar', 'lionel', 'malik', 'ebony', 'jasmine', 'tia',
                                      'hakim', 'kareem', 'jamal', 'kenya'],
                        'second_set': ['adam', 'chip', 'harry', 'josh', 'roger', 'alan', 'frank', 'ian', 'justin',
                                       'ryan', 'andrew', 'fred', 'jack']
                    },
                'fasttext':
                    {
                        'first_set': ['alonzo', 'jamel', 'theo', 'alphonse', 'jerome', 'leroy', 'torrance', 'darnell',
                                      'lamar', 'lionel', 'tyree', 'lamont', 'malik', 'terrence', 'tyrone', 'marcellus',
                                      'ebony', 'jasmine', 'tanisha', 'tia', 'latoya', 'yolanda', 'malika', 'yvette',
                                      'hakim', 'jermaine', 'kareem', 'jamal', 'aisha', 'keisha', 'kenya'],
                        'second_set': ['adam', 'chip', 'harry', 'josh', 'roger', 'alan', 'frank', 'ian', 'justin',
                                       'ryan', 'andrew', 'fred', 'jack', 'matthew', 'stephen', 'brad', 'jed', 'todd',
                                       'brandon', 'hank', 'jonathan', 'peter', 'wilbur', 'amanda', 'courtney',
                                       'heather', 'melanie', 'sara', 'amber', 'crystal', 'katie', 'meredith', 'shannon',
                                       'betsy']
                    },
                'glove':
                    {
                        'first_set': ['alonzo', 'jamel', 'theo', 'alphonse', 'jerome', 'leroy', 'torrance', 'darnell',
                                      'lamar', 'lionel', 'tyree', 'lamont', 'malik', 'terrence', 'tyrone', 'marcellus',
                                      'ebony', 'jasmine', 'tanisha', 'tia', 'latoya', 'yolanda', 'malika', 'yvette',
                                      'hakim', 'jermaine', 'kareem', 'jamal', 'aisha', 'keisha', 'kenya'],
                        'second_set': ['adam', 'chip', 'harry', 'josh', 'roger', 'alan', 'frank', 'ian', 'justin',
                                       'ryan', 'andrew', 'fred', 'jack', 'matthew', 'stephen', 'brad', 'jed', 'todd',
                                       'brandon', 'hank', 'jonathan', 'peter', 'wilbur', 'amanda', 'courtney',
                                       'heather', 'melanie', 'sara', 'amber', 'crystal', 'katie', 'meredith', 'shannon',
                                       'betsy', 'kristin', 'nancy', 'stephanie', 'ellen', 'lauren', 'peggy', 'colleen']
                    }
            },
        'male_female':
            {
                'glove':
                    {'first_set': ['male', 'man', 'boy', 'brother', 'him', 'son', 'father', 'uncle', 'grandfather'],
                     'second_set': ['female', 'woman', 'girl', 'sister', 'her', 'daughter', 'mother', 'aunt',
                                    'grandmother']},
                'word2vec':
                    {'first_set': ['male', 'man', 'boy', 'brother', 'him', 'son', 'father', 'uncle', 'grandfather'],
                     'second_set': ['female', 'woman', 'girl', 'sister', 'her', 'daughter', 'mother', 'aunt',
                                    'grandmother']},
                'fasttext':
                    {'first_set': ['male', 'man', 'boy', 'brother', 'him', 'son', 'father', 'uncle', 'grandfather'],
                     'second_set': ['female', 'woman', 'girl', 'sister', 'her', 'daughter', 'mother', 'aunt',
                                    'grandmother']}
            },
        'islam_christianity':
            {
                "fasttext":
                    {"first_set": ["allah", "ramadan", "emir", "salaam", "koran", "imam", "sultan", "prophet", "veil",
                                   "ayatollah", "mosque"],
                     "second_set": ["baptism", "messiah", "catholicism", "resurrection", "christianity", "salvation",
                                    "protestant", "gospel", "trinity", "jesus", "christ", "christian", "cross",
                                    "catholic"]
                     },
                "glove":
                    {"first_set": ["allah", "ramadan", "emir", "salaam", "koran", "imam", "sultan", "prophet", "veil",
                                   "ayatollah", "mosque", "islam"],
                     "second_set": ["baptism", "messiah", "catholicism", "resurrection", "christianity", "salvation",
                                    "protestant", "gospel", "trinity", "jesus", "christ", "christian", "cross",
                                    "catholic", "church"]
                     },
                "word2vec": {
                    "first_set": ["allah", "ramadan", "emir", "salaam", "koran", "imam", "sultan", "prophet", "veil",
                                  "ayatollah"],
                    "second_set": ["baptism", "messiah", "catholicism", "resurrection", "christianity", "salvation",
                                   "protestant", "gospel", "trinity", "jesus", "christ", "christian", "cross"]}
            }
    }

    return dictionary_categories, parameters_dict, target_sets_dict

# %%
def filter_emb(target_sets, word_index):
    """
    Filtering opposite target sets to be equal size and using only ones in embedding

    Parameters
    ----------
    target_sets: dict | target_sets_dict from sets.get_sent_analysis_sets() method
    word_index: dict | Word as a key and index as value

    Returns
    -------
    filtered_word_index: dict | Two opposing sets of words
    """
    lengths = [0, 0]
    for i, key_idx in enumerate(list(target_sets.keys())):
        target_sets[key_idx] = [word for word in target_sets[key_idx] if word in word_index]
        lengths[i] = len(target_sets[key_idx])

    return {key_idx: word_list[0:min(lengths)] for key_idx, word_list in target_sets.items()}

# %%
def null_intersection(x_train, y_train, target_words, word_index):
    """
    Eliminating training set that contains target words

    Parameters
    ----------
    x_train: ndarray | Training data
    y_train: ndarray | Label data
    target_words: list | List of target words to exclude from learning procedure
    word_index: dict | Word to index mapping

    Returns
    -------
    x_train_new: ndarray | Training data
    y_train_new: ndarray | Label data
    """
    x_train_new, y_train_new = [], []

    for i, x_t in enumerate(x_train):
        intersection = len(set(x_t).intersection([word_index[word] for word in target_words]))
        if intersection == 0:
            x_train_new.append(x_t)
            y_train_new.append(y_train[i])

    return x_train_new, y_train_new

# %%
def compare_embeddings(datasets, embeddings, params, number_of_models = 6):

    '''
    Comparing different levels of debiasing based on Sentiment Analysis task

    Parameters
    ----------
    datasets: dict | From utils.get_dataset_and_dicts() method
    embeddings: dict | Keys as embedding types (original, hardweat, softweat) and Embedding instances as values
    params: dict | From sets.get_sent_analysis_sets() method
    number_of_models: int | Number of different models from which polarity score will be generated
    '''

    keys = list(datasets['targets_sets'].keys())
    emb_mod = {'No sentence modified': (datasets['x_test_padded'], datasets['y_test']),
             'First set modification': change_the_sentences(datasets, keys[0]),
             'Second set modification': change_the_sentences(datasets, keys[1])}
    results = {'original': [], 'hardweat': [], 'softweat': []}
    x_train_fit, y_train_fit = datasets['x_train_padded'], datasets['y_train']

    for emb_type, e in embeddings.items():

        emb_matrix = np.zeros((params['NB_WORDS'], params['EMB_DIM']))
        set_words = set(e.words)
        for word, i in datasets['word_2_index'].items():
            if word not in set_words or i >= params['NB_WORDS']: continue
            else: emb_matrix[i] = e.get_value(word);

        for j in range(0, 6):

            keras_model = Keras_Model(params)
            keras_model.model.layers[0].set_weights([emb_matrix])
            keras_model.model.layers[0].trainable = keras_model.model.layers[1].trainable = False
            keras_model.model.compile(loss = 'binary_crossentropy', optimizer='adadelta',metrics = ['accuracy']) 
            keras_model.model.fit(x_train_fit, y_train_fit, epochs=8, verbose=0)
                
            polarity_scores = {'No sentence modified':[], 'First set modification':[], 'Second set modification':[]}
            cnf_scores = {'No sentence modified':[], 'First set modification':[], 'Second set modification':[]}

            for i, (key, (x_t, y_t)) in enumerate(emb_mod.items()):

                prediction_results = keras_model.model.predict(x_t) 
                polarity_scores[key] = np.array(prediction_results)[:,0]
                prediction_results = [1 if output_instance>0.5 else 0 for output_instance in prediction_results]
                correct_results = y_t
                cnf_scores[key].append(metrics.confusion_matrix(correct_results, prediction_results))

            final_polarity = [polarity_scores['First set modification'][i]-polarity_scores['Second set modification'][i] for i in range(0, len(polarity_scores['Second set modification']))]
            results[emb_type].append((final_polarity, cnf_scores))
            print(f'F1 score for {emb_type} embedding, {j+1}.model: {round(metrics.f1_score(correct_results, prediction_results),2)}')

        print('________________________________________________________________')

    return results

# %%
dictionary_categories, parameters_dict, target_sets_dict = get_sent_analysis_sets()

# %%
target_pairs = ['islam_christianity', 'male_female', 'black_white']
target_pair = target_pairs[0]

# %%
emb_name='word2vec'

# %%
target_sets_dict[target_pair][emb_name]
# Out:
# {'first_set': ['allah',
#   'ramadan',
#   'emir',
#   'salaam',
#   'koran',
#   'imam',
#   'sultan',
#   'prophet',
#   'veil',
#   'ayatollah'],
#  'second_set': ['baptism',
#   'messiah',
#   'catholicism',
#   'resurrection',
#   'christianity',
#   'salvation',
#   'protestant',
#   'gospel',
#   'trinity',
#   'jesus',
#   'christ',
#   'christian',
#   'cross']}

# %%
parameters_dict
# Out:
# {'NB_WORDS': 124252, 'MAX_LEN': 50, 'NO_PRETR_DIM': 100, 'EMB_DIM': 300}

# %%
datasets_and_dicts = get_dataset_and_dicts( target_sets_dict[target_pair][emb_name], parameters_dict)

# %%
targets_sets=target_sets_dict[target_pair][emb_name]
params=parameters_dict

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
from keras_preprocessing.text import Tokenizer

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from keras_preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv('data/IMDB_Dataset.csv')
df = df.reindex(np.random.permutation(df.index))
X_train, X_test, y_train, y_test = train_test_split(df.review, df.sentiment, shuffle=False)

# %%
tk = Tokenizer(num_words=params["NB_WORDS"])

# %%
tk.fit_on_texts(df.review)

# %%
x_train = tk.texts_to_sequences(X_train)
x_test = tk.texts_to_sequences(X_test)

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
# Filtering input to satisfy learning constraints
targets_sets = filter_emb(targets_sets, tk.word_index)

# %%
x_train, y_train = null_intersection(x_train, y_train,
                                         set([word for set_name in targets_sets for word in targets_sets[set_name]]),
                                         tk.word_index)

# %%
x_train_copy, x_test_copy, y_train_copy, y_test_copy = [], [], [], []

# %%
for i in range(0, len(x_train)):
    if len(x_train[i]) < params['MAX_LEN']:
        x_train_copy.append(x_train[i])
        y_train_copy.append(y_train[i])

for i in range(0, len(x_test)):
    if len(x_test[i]) < params['MAX_LEN']:
        x_test_copy.append(x_test[i])
        y_test_copy.append(y_test[i])

# %%
x_train_padded = pad_sequences(x_train_copy, maxlen=params['MAX_LEN'], padding='post')
x_test_padded = pad_sequences(x_test_copy, maxlen=params['MAX_LEN'], padding='post')

# %%
print(f'Training shape: {x_train_padded.shape}\nTest shape: {x_test_padded.shape}')
# Out:
# Training shape: (827, 50)
# Test shape: (283, 50)

# %%
datasets = {'x_train': np.array(x_train_copy), 'x_test': np.array(x_test_copy),
            'x_train_padded': np.array(x_train_padded), 'x_test_padded': np.array(x_test_padded),
            'y_train': np.array(y_train_copy), 'y_test': np.array(y_test_copy),
            'word_2_index': tk.word_index, 'index_2_word': tk.index_word, 'targets_sets': targets_sets}

# %%
embedding = Word_Embedding('glove-twitter-25d-10000f')
# Out:
# Regular embedding successfully read. Shape: (10000, 25)

# %%
embedding2=Word_Embedding('glove-twitter-25d-10000f')
# Out:
# Regular embedding successfully read. Shape: (10000, 25)

# %%
embeddings_dict = {'original': embedding, 'hardweat': embedding2, 'softweat': embedding2}

# %%
datasets_and_dicts=datasets

# %%
results = compare_embeddings(datasets_and_dicts, embeddings_dict, parameters_dict)
# Out:
# Shape of modified test input: (100, 50)
# Shape of modified test input: (100, 50)
# Word the not in the Embedding.
# Word and not in the Embedding.
# Word of not in the Embedding.
# Word to not in the Embedding.
# Word is not in the Embedding.
# Word br not in the Embedding.
# Word in not in the Embedding.
# Word it not in the Embedding.
# Word this not in the Embedding.
# Word that not in the Embedding.
# Word was not in the Embedding.
# Word as not in the Embedding.
# Word for not in the Embedding.
# Word with not in the Embedding.
# Word movie not in the Embedding.
# Word but not in the Embedding.
# Word film not in the Embedding.
# Word on not in the Embedding.
# Word not not in the Embedding.
# Word you not in the Embedding.
# Word are not in the Embedding.
# Word his not in the Embedding.
# Word have not in the Embedding.
# Word be not in the Embedding.
# Word one not in the Embedding.
# Word he not in the Embedding.
# Word all not in the Embedding.
# Word at not in the Embedding.
# Word by not in the Embedding.
# Word an not in the Embedding.
# Word they not in the Embedding.
# Word so not in the Embedding.
# Word who not in the Embedding.
# Word from not in the Embedding.
# Word like not in the Embedding.
# Word or not in the Embedding.
# Word just not in the Embedding.
# Word her not in the Embedding.
# Word out not in the Embedding.
# Word about not in the Embedding.
# Word if not in the Embedding.
# Word has not in the Embedding.
# Word there not in the Embedding.
# Word some not in the Embedding.
# Word what not in the Embedding.
# Word good not in the Embedding.
# Word when not in the Embedding.
# Word more not in the Embedding.
# Word very not in the Embedding.
# Word up not in the Embedding.
# Word no not in the Embedding.
# Word time not in the Embedding.
# Word my not in the Embedding.
# Word even not in the Embedding.
# Word would not in the Embedding.
# Word she not in the Embedding.
# Word which not in the Embedding.
# Word only not in the Embedding.
# Word really not in the Embedding.
# Word see not in the Embedding.
# Word story not in the Embedding.
# Word their not in the Embedding.
# Word had not in the Embedding.
# Word can not in the Embedding.
# Word me not in the Embedding.
# Word well not in the Embedding.
# Word were not in the Embedding.
# Word than not in the Embedding.
# Word much not in the Embedding.
# Word we not in the Embedding.
# Word bad not in the Embedding.
# Word been not in the Embedding.
# Word get not in the Embedding.
# Word do not in the Embedding.
# Word great not in the Embedding.
# Word other not in the Embedding.
# Word will not in the Embedding.
# Word also not in the Embedding.
# Word into not in the Embedding.
# Word people not in the Embedding.
# Word because not in the Embedding.
# Word how not in the Embedding.
# Word first not in the Embedding.
# Word him not in the Embedding.
# Word most not in the Embedding.
# Word made not in the Embedding.
# Word then not in the Embedding.
# Word its not in the Embedding.
# Word them not in the Embedding.
# Word make not in the Embedding.
# Word way not in the Embedding.
# Word too not in the Embedding.
# Word movies not in the Embedding.
# Word could not in the Embedding.
# Word any not in the Embedding.
# Word after not in the Embedding.
# Word think not in the Embedding.
# Word characters not in the Embedding.
# Word watch not in the Embedding.
# Word films not in the Embedding.
# Word two not in the Embedding.
# Word many not in the Embedding.
# Word seen not in the Embedding.
# Word character not in the Embedding.
# Word being not in the Embedding.
# Word never not in the Embedding.
# Word plot not in the Embedding.
# Word love not in the Embedding.
# Word acting not in the Embedding.
# Word life not in the Embedding.
# Word did not in the Embedding.
# Word best not in the Embedding.
# Word where not in the Embedding.
# Word know not in the Embedding.
# Word show not in the Embedding.
# Word little not in the Embedding.
# Word over not in the Embedding.
# Word off not in the Embedding.
# Word ever not in the Embedding.
# Word does not in the Embedding.
# Word your not in the Embedding.
# Word better not in the Embedding.
# Word end not in the Embedding.
# Word man not in the Embedding.
# Word scene not in the Embedding.
# Word still not in the Embedding.
# Word say not in the Embedding.
# Word these not in the Embedding.
# Word here not in the Embedding.
# Word why not in the Embedding.
# Word scenes not in the Embedding.
# Word while not in the Embedding.
# Word something not in the Embedding.
# Word such not in the Embedding.
# Word go not in the Embedding.
# Word through not in the Embedding.
# Word back not in the Embedding.
# Word should not in the Embedding.
# Word those not in the Embedding.
# Word real not in the Embedding.
# Word now not in the Embedding.
# Word watching not in the Embedding.
# Word thing not in the Embedding.
# Word though not in the Embedding.
# Word funny not in the Embedding.
# Word years not in the Embedding.
# Word old not in the Embedding.
# Word another not in the Embedding.
# Word work not in the Embedding.
# Word before not in the Embedding.
# Word actually not in the Embedding.
# Word nothing not in the Embedding.
# Word makes not in the Embedding.
# Word look not in the Embedding.
# Word director not in the Embedding.
# Word find not in the Embedding.
# Word going not in the Embedding.
# Word same not in the Embedding.
# Word new not in the Embedding.
# Word lot not in the Embedding.
# Word every not in the Embedding.
# Word few not in the Embedding.
# Word again not in the Embedding.
# Word part not in the Embedding.
# Word cast not in the Embedding.
# Word down not in the Embedding.
# Word us not in the Embedding.
# Word things not in the Embedding.
# Word want not in the Embedding.
# Word quite not in the Embedding.
# Word pretty not in the Embedding.
# Word world not in the Embedding.
# Word horror not in the Embedding.
# Word around not in the Embedding.
# Word seems not in the Embedding.
# Word young not in the Embedding.
# Word take not in the Embedding.
# Word however not in the Embedding.
# Word got not in the Embedding.
# Word thought not in the Embedding.
# Word big not in the Embedding.
# Word fact not in the Embedding.
# Word enough not in the Embedding.
# Word long not in the Embedding.
# Word both not in the Embedding.
# Word give not in the Embedding.
# Word own not in the Embedding.
# Word may not in the Embedding.
# Word between not in the Embedding.
# Word comedy not in the Embedding.
# Word right not in the Embedding.
# Word series not in the Embedding.
# Word action not in the Embedding.
# Word must not in the Embedding.
# Word music not in the Embedding.
# Word without not in the Embedding.
# Word times not in the Embedding.
# Word saw not in the Embedding.
# Word always not in the Embedding.
# Word original not in the Embedding.
# Word role not in the Embedding.
# Word come not in the Embedding.
# Word almost not in the Embedding.
# Word gets not in the Embedding.
# Word interesting not in the Embedding.
# Word guy not in the Embedding.
# Word point not in the Embedding.
# Word done not in the Embedding.
# Word whole not in the Embedding.
# Word least not in the Embedding.
# Word far not in the Embedding.
# Word bit not in the Embedding.
# Word script not in the Embedding.
# Word minutes not in the Embedding.
# Word feel not in the Embedding.
# Word anything not in the Embedding.
# Word making not in the Embedding.
# Word might not in the Embedding.
# Word since not in the Embedding.
# Word am not in the Embedding.
# Word family not in the Embedding.
# Word last not in the Embedding.
# Word probably not in the Embedding.
# Word tv not in the Embedding.
# Word performance not in the Embedding.
# Word kind not in the Embedding.
# Word away not in the Embedding.
# Word yet not in the Embedding.
# Word fun not in the Embedding.
# Word worst not in the Embedding.
# Word sure not in the Embedding.
# Word rather not in the Embedding.
# Word hard not in the Embedding.
# Word anyone not in the Embedding.
# Word girl not in the Embedding.
# Word each not in the Embedding.
# Word played not in the Embedding.
# Word day not in the Embedding.
# Word found not in the Embedding.
# Word looking not in the Embedding.
# Word woman not in the Embedding.
# Word screen not in the Embedding.
# Word although not in the Embedding.
# Word our not in the Embedding.
# Word especially not in the Embedding.
# Word believe not in the Embedding.
# Word having not in the Embedding.
# Word trying not in the Embedding.
# Word course not in the Embedding.
# Word dvd not in the Embedding.
# Word everything not in the Embedding.
# Word set not in the Embedding.
# Word goes not in the Embedding.
# Word comes not in the Embedding.
# Word put not in the Embedding.
# Word ending not in the Embedding.
# Word maybe not in the Embedding.
# Word place not in the Embedding.
# Word book not in the Embedding.
# Word shows not in the Embedding.
# Word three not in the Embedding.
# Word worth not in the Embedding.
# Word different not in the Embedding.
# Word main not in the Embedding.
# Word once not in the Embedding.
# Word sense not in the Embedding.
# Word american not in the Embedding.
# Word reason not in the Embedding.
# Word looks not in the Embedding.
# Word watched not in the Embedding.
# Word play not in the Embedding.
# Word true not in the Embedding.
# Word money not in the Embedding.
# Word actor not in the Embedding.
# Word job not in the Embedding.
# Word together not in the Embedding.
# Word war not in the Embedding.
# Word someone not in the Embedding.
# Word plays not in the Embedding.
# Word instead not in the Embedding.
# Word high not in the Embedding.
# Word during not in the Embedding.
# Word said not in the Embedding.
# Word year not in the Embedding.
# Word half not in the Embedding.
# Word everyone not in the Embedding.
# Word later not in the Embedding.
# Word takes not in the Embedding.
# Word seem not in the Embedding.
# Word audience not in the Embedding.
# Word special not in the Embedding.
# Word beautiful not in the Embedding.
# Word left not in the Embedding.
# Word himself not in the Embedding.
# Word seeing not in the Embedding.
# Word john not in the Embedding.
# Word night not in the Embedding.
# Word black not in the Embedding.
# Word version not in the Embedding.
# Word shot not in the Embedding.
# Word excellent not in the Embedding.
# Word idea not in the Embedding.
# Word house not in the Embedding.
# Word mind not in the Embedding.
# Word star not in the Embedding.
# Word wife not in the Embedding.
# Word fan not in the Embedding.
# Word death not in the Embedding.
# Word used not in the Embedding.
# Word else not in the Embedding.
# Word simply not in the Embedding.
# Word nice not in the Embedding.
# Word budget not in the Embedding.
# Word poor not in the Embedding.
# Word completely not in the Embedding.
# Word short not in the Embedding.
# Word second not in the Embedding.
# Word read not in the Embedding.
# Word less not in the Embedding.
# Word along not in the Embedding.
# Word top not in the Embedding.
# Word help not in the Embedding.
# Word home not in the Embedding.
# Word men not in the Embedding.
# Word either not in the Embedding.
# Word line not in the Embedding.
# Word boring not in the Embedding.
# Word dead not in the Embedding.
# Word friends not in the Embedding.
# Word kids not in the Embedding.
# Word try not in the Embedding.
# Word production not in the Embedding.
# Word enjoy not in the Embedding.
# Word camera not in the Embedding.
# Word use not in the Embedding.
# Word wrong not in the Embedding.
# Word given not in the Embedding.
# Word low not in the Embedding.
# Word classic not in the Embedding.
# Word father not in the Embedding.
# Word need not in the Embedding.
# Word full not in the Embedding.
# Word stupid not in the Embedding.
# Word next not in the Embedding.
# Word until not in the Embedding.
# Word school not in the Embedding.
# Word hollywood not in the Embedding.
# Word rest not in the Embedding.
# Word truly not in the Embedding.
# Word awful not in the Embedding.
# Word video not in the Embedding.
# Word couple not in the Embedding.
# Word start not in the Embedding.
# Word sex not in the Embedding.
# Word recommend not in the Embedding.
# Word women not in the Embedding.
# Word let not in the Embedding.
# Word tell not in the Embedding.
# Word terrible not in the Embedding.
# Word remember not in the Embedding.
# Word mean not in the Embedding.
# Word came not in the Embedding.
# Word getting not in the Embedding.
# Word understand not in the Embedding.
# Word perhaps not in the Embedding.
# Word moments not in the Embedding.
# Word name not in the Embedding.
# Word keep not in the Embedding.
# Word face not in the Embedding.
# Word itself not in the Embedding.
# Word wonderful not in the Embedding.
# Word playing not in the Embedding.
# Word human not in the Embedding.
# Word style not in the Embedding.
# Word small not in the Embedding.
# Word episode not in the Embedding.
# Word perfect not in the Embedding.
# Word others not in the Embedding.
# Word person not in the Embedding.
# Word doing not in the Embedding.
# Word often not in the Embedding.
# Word early not in the Embedding.
# Word stars not in the Embedding.
# Word definitely not in the Embedding.
# Word written not in the Embedding.
# Word head not in the Embedding.
# Word lines not in the Embedding.
# Word gives not in the Embedding.
# Word piece not in the Embedding.
# Word went not in the Embedding.
# Word finally not in the Embedding.
# Word mother not in the Embedding.
# Word title not in the Embedding.
# Word case not in the Embedding.
# Word absolutely not in the Embedding.
# Word live not in the Embedding.
# Word boy not in the Embedding.
# Word yes not in the Embedding.
# Word laugh not in the Embedding.
# Word certainly not in the Embedding.
# Word liked not in the Embedding.
# Word become not in the Embedding.
# Word worse not in the Embedding.
# Word entertaining not in the Embedding.
# Word oh not in the Embedding.
# Word sort not in the Embedding.
# Word loved not in the Embedding.
# Word lost not in the Embedding.
# Word hope not in the Embedding.
# Word called not in the Embedding.
# Word picture not in the Embedding.
# Word felt not in the Embedding.
# Word entire not in the Embedding.
# Word several not in the Embedding.
# Word mr not in the Embedding.
# Word based not in the Embedding.
# Word supposed not in the Embedding.
# Word cinema not in the Embedding.
# Word friend not in the Embedding.
# Word guys not in the Embedding.
# Word sound not in the Embedding.
# Word problem not in the Embedding.
# Word drama not in the Embedding.
# Word against not in the Embedding.
# Word waste not in the Embedding.
# Word white not in the Embedding.
# Word beginning not in the Embedding.
# Word fans not in the Embedding.
# Word totally not in the Embedding.
# Word dark not in the Embedding.
# Word care not in the Embedding.
# Word direction not in the Embedding.
# Word humor not in the Embedding.
# Word wanted not in the Embedding.
# Word game not in the Embedding.
# Word under not in the Embedding.
# Word children not in the Embedding.
# Word despite not in the Embedding.
# Word lives not in the Embedding.
# Word lead not in the Embedding.
# Word guess not in the Embedding.
# Word example not in the Embedding.
# Word already not in the Embedding.
# Word final not in the Embedding.
# Word throughout not in the Embedding.
# Word evil not in the Embedding.
# Word turn not in the Embedding.
# Word becomes not in the Embedding.
# Word unfortunately not in the Embedding.
# Word able not in the Embedding.
# Word quality not in the Embedding.
# Word days not in the Embedding.
# Word history not in the Embedding.
# Word fine not in the Embedding.
# Word side not in the Embedding.
# Word wants not in the Embedding.
# Word horrible not in the Embedding.
# Word heart not in the Embedding.
# Word writing not in the Embedding.
# Word amazing not in the Embedding.
# Word killer not in the Embedding.
# Word run not in the Embedding.
# Word son not in the Embedding.
# Word michael not in the Embedding.
# Word works not in the Embedding.
# Word close not in the Embedding.
# Word act not in the Embedding.
# Word art not in the Embedding.
# Word matter not in the Embedding.
# Word kill not in the Embedding.
# Word etc not in the Embedding.
# Word tries not in the Embedding.
# Word past not in the Embedding.
# Word town not in the Embedding.
# Word enjoyed not in the Embedding.
# Word turns not in the Embedding.
# Word brilliant not in the Embedding.
# Word gave not in the Embedding.
# Word behind not in the Embedding.
# Word parts not in the Embedding.
# Word stuff not in the Embedding.
# Word genre not in the Embedding.
# Word eyes not in the Embedding.
# Word car not in the Embedding.
# Word favorite not in the Embedding.
# Word late not in the Embedding.
# Word hand not in the Embedding.
# Word expect not in the Embedding.
# Word soon not in the Embedding.
# Word hour not in the Embedding.
# Word obviously not in the Embedding.
# Word themselves not in the Embedding.
# Word sometimes not in the Embedding.
# Word killed not in the Embedding.
# Word actress not in the Embedding.
# Word thinking not in the Embedding.
# Word girls not in the Embedding.
# Word child not in the Embedding.
# Word starts not in the Embedding.
# Word city not in the Embedding.
# Word myself not in the Embedding.
# Word decent not in the Embedding.
# Word highly not in the Embedding.
# Word stop not in the Embedding.
# Word type not in the Embedding.
# Word self not in the Embedding.
# Word god not in the Embedding.
# Word says not in the Embedding.
# Word group not in the Embedding.
# Word anyway not in the Embedding.
# Word voice not in the Embedding.
# Word took not in the Embedding.
# Word known not in the Embedding.
# Word blood not in the Embedding.
# Word kid not in the Embedding.
# Word heard not in the Embedding.
# Word happens not in the Embedding.
# Word except not in the Embedding.
# Word fight not in the Embedding.
# Word feeling not in the Embedding.
# Word experience not in the Embedding.
# Word coming not in the Embedding.
# Word slow not in the Embedding.
# Word daughter not in the Embedding.
# Word writer not in the Embedding.
# Word stories not in the Embedding.
# Word moment not in the Embedding.
# Word leave not in the Embedding.
# Word told not in the Embedding.
# Word extremely not in the Embedding.
# Word score not in the Embedding.
# Word violence not in the Embedding.
# Word police not in the Embedding.
# Word involved not in the Embedding.
# Word strong not in the Embedding.
# Word chance not in the Embedding.
# Word lack not in the Embedding.
# Word cannot not in the Embedding.
# Word hit not in the Embedding.
# Word hilarious not in the Embedding.
# Word happen not in the Embedding.
# Word wonder not in the Embedding.
# Word ok not in the Embedding.
# Word including not in the Embedding.
# Word living not in the Embedding.
# Word save not in the Embedding.
# Word looked not in the Embedding.
# Word crap not in the Embedding.
# Word simple not in the Embedding.
# Word please not in the Embedding.
# Word cool not in the Embedding.
# Word murder not in the Embedding.
# Word obvious not in the Embedding.
# Word happened not in the Embedding.
# Word complete not in the Embedding.
# Word cut not in the Embedding.
# Word serious not in the Embedding.
# Word age not in the Embedding.
# Word attempt not in the Embedding.
# Word hell not in the Embedding.
# Word ago not in the Embedding.
# Word song not in the Embedding.
# Word taken not in the Embedding.
# Word english not in the Embedding.
# Word james not in the Embedding.
# Word robert not in the Embedding.
# Word david not in the Embedding.
# Word seriously not in the Embedding.
# Word released not in the Embedding.
# Word reality not in the Embedding.
# Word opening not in the Embedding.
# Word jokes not in the Embedding.
# Word interest not in the Embedding.
# Word across not in the Embedding.
# Word none not in the Embedding.
# Word hero not in the Embedding.
# Word possible not in the Embedding.
# Word exactly not in the Embedding.
# Word today not in the Embedding.
# Word alone not in the Embedding.
# Word sad not in the Embedding.
# Word brother not in the Embedding.
# Word number not in the Embedding.
# Word career not in the Embedding.
# Word saying not in the Embedding.
# Word hours not in the Embedding.
# Word usually not in the Embedding.
# Word talent not in the Embedding.
# Word view not in the Embedding.
# Word yourself not in the Embedding.
# Word running not in the Embedding.
# Word annoying not in the Embedding.
# Word relationship not in the Embedding.
# Word wish not in the Embedding.
# Word huge not in the Embedding.
# Word order not in the Embedding.
# Word shots not in the Embedding.
# Word whose not in the Embedding.
# Word ridiculous not in the Embedding.
# Word taking not in the Embedding.
# Word important not in the Embedding.
# Word light not in the Embedding.
# Word body not in the Embedding.
# Word middle not in the Embedding.
# Word level not in the Embedding.
# Word ends not in the Embedding.
# Word call not in the Embedding.
# Word started not in the Embedding.
# Word female not in the Embedding.
# Word husband not in the Embedding.
# Word four not in the Embedding.
# Word power not in the Embedding.
# Word turned not in the Embedding.
# Word major not in the Embedding.
# Word word not in the Embedding.
# Word opinion not in the Embedding.
# Word change not in the Embedding.
# Word mostly not in the Embedding.
# Word usual not in the Embedding.
# Word silly not in the Embedding.
# Word scary not in the Embedding.
# Word beyond not in the Embedding.
# Word ones not in the Embedding.
# Word happy not in the Embedding.
# Word words not in the Embedding.
# Word room not in the Embedding.
# Word knew not in the Embedding.
# Word knows not in the Embedding.
# Word country not in the Embedding.
# Word disappointed not in the Embedding.
# Word talking not in the Embedding.
# Word novel not in the Embedding.
# Word apparently not in the Embedding.
# Word non not in the Embedding.
# Word strange not in the Embedding.
# Word attention not in the Embedding.
# Word upon not in the Embedding.
# Word basically not in the Embedding.
# Word single not in the Embedding.
# Word finds not in the Embedding.
# Word cheap not in the Embedding.
# Word modern not in the Embedding.
# Word due not in the Embedding.
# Word jack not in the Embedding.
# Word television not in the Embedding.
# Word musical not in the Embedding.
# Word problems not in the Embedding.
# Word miss not in the Embedding.
# Word episodes not in the Embedding.
# Word clearly not in the Embedding.
# Word local not in the Embedding.
# Word british not in the Embedding.
# Word talk not in the Embedding.
# Word events not in the Embedding.
# Word five not in the Embedding.
# Word class not in the Embedding.
# Word french not in the Embedding.
# Word moving not in the Embedding.
# Word ten not in the Embedding.
# Word fast not in the Embedding.
# Word review not in the Embedding.
# Word earth not in the Embedding.
# Word tells not in the Embedding.
# Word team not in the Embedding.
# Word songs not in the Embedding.
# Word comic not in the Embedding.
# Word straight not in the Embedding.
# Word whether not in the Embedding.
# Word die not in the Embedding.
# Word add not in the Embedding.
# Word entertainment not in the Embedding.
# Word above not in the Embedding.
# Word sets not in the Embedding.
# Word future not in the Embedding.
# Word near not in the Embedding.
# Word space not in the Embedding.
# Word easily not in the Embedding.
# Word hate not in the Embedding.
# Word soundtrack not in the Embedding.
# Word bring not in the Embedding.
# Word giving not in the Embedding.
# Word lots not in the Embedding.
# Word similar not in the Embedding.
# Word romantic not in the Embedding.
# Word george not in the Embedding.
# Word supporting not in the Embedding.
# Word release not in the Embedding.
# Word mention not in the Embedding.
# Word within not in the Embedding.
# Word message not in the Embedding.
# Word clear not in the Embedding.
# Word falls not in the Embedding.
# Word needs not in the Embedding.
# Word eye not in the Embedding.
# Word bunch not in the Embedding.
# Word surprised not in the Embedding.
# Word showing not in the Embedding.
# Word sorry not in the Embedding.
# Word tried not in the Embedding.
# Word certain not in the Embedding.
# Word easy not in the Embedding.
# Word working not in the Embedding.
# Word ways not in the Embedding.
# Word theme not in the Embedding.
# Word theater not in the Embedding.
# Word among not in the Embedding.
# Word named not in the Embedding.
# Word monster not in the Embedding.
# Word king not in the Embedding.
# Word stay not in the Embedding.
# Word effort not in the Embedding.
# Word stand not in the Embedding.
# Word fall not in the Embedding.
# Word minute not in the Embedding.
# Word gone not in the Embedding.
# Word rock not in the Embedding.
# Word using not in the Embedding.
# Word feature not in the Embedding.
# Word comments not in the Embedding.
# Word buy not in the Embedding.
# Word typical not in the Embedding.
# Word sister not in the Embedding.
# Word avoid not in the Embedding.
# Word deal not in the Embedding.
# Word mystery not in the Embedding.
# Word dr not in the Embedding.
# Word doubt not in the Embedding.
# Word fantastic not in the Embedding.
# Word nearly not in the Embedding.
# Word kept not in the Embedding.
# Word feels not in the Embedding.
# Word okay not in the Embedding.
# Word subject not in the Embedding.
# Word check not in the Embedding.
# Word oscar not in the Embedding.
# Word points not in the Embedding.
# Word greatest not in the Embedding.
# Word means not in the Embedding.
# Word herself not in the Embedding.
# Word parents not in the Embedding.
# Word famous not in the Embedding.
# Word imagine not in the Embedding.
# Word rent not in the Embedding.
# Word richard not in the Embedding.
# Word crime not in the Embedding.
# Word form not in the Embedding.
# Word peter not in the Embedding.
# Word actual not in the Embedding.
# Word lady not in the Embedding.
# Word general not in the Embedding.
# Word dog not in the Embedding.
# Word follow not in the Embedding.
# Word period not in the Embedding.
# Word red not in the Embedding.
# Word move not in the Embedding.
# Word brought not in the Embedding.
# Word material not in the Embedding.
# Word forget not in the Embedding.
# Word somehow not in the Embedding.
# Word begins not in the Embedding.
# Word re not in the Embedding.
# Word reviews not in the Embedding.
# Word paul not in the Embedding.
# Word leads not in the Embedding.
# Word weak not in the Embedding.
# Word figure not in the Embedding.
# Word surprise not in the Embedding.
# Word sit not in the Embedding.
# Word hear not in the Embedding.
# Word average not in the Embedding.
# Word open not in the Embedding.
# Word killing not in the Embedding.
# Word eventually not in the Embedding.
# Word learn not in the Embedding.
# Word tom not in the Embedding.
# Word wait not in the Embedding.
# Word deep not in the Embedding.
# Word fi not in the Embedding.
# Word expected not in the Embedding.
# Word whatever not in the Embedding.
# Word indeed not in the Embedding.
# Word lame not in the Embedding.
# Word note not in the Embedding.
# Word particular not in the Embedding.
# Word dance not in the Embedding.
# Word shame not in the Embedding.
# Word situation not in the Embedding.
# Word third not in the Embedding.
# Word box not in the Embedding.
# Word york not in the Embedding.
# Word truth not in the Embedding.
# Word decided not in the Embedding.
# Word free not in the Embedding.
# Word hot not in the Embedding.
# Word difficult not in the Embedding.
# Word season not in the Embedding.
# Word needed not in the Embedding.
# Word leaves not in the Embedding.
# Word unless not in the Embedding.
# Word emotional not in the Embedding.
# Word romance not in the Embedding.
# Word possibly not in the Embedding.
# Word sexual not in the Embedding.
# Word gay not in the Embedding.
# Word boys not in the Embedding.
# Word write not in the Embedding.
# Word western not in the Embedding.
# Word forced not in the Embedding.
# Word reading not in the Embedding.
# Word became not in the Embedding.
# Word doctor not in the Embedding.
# Word otherwise not in the Embedding.
# Word crew not in the Embedding.
# Word air not in the Embedding.
# Word begin not in the Embedding.
# Word de not in the Embedding.
# Word question not in the Embedding.
# Word meet not in the Embedding.
# Word society not in the Embedding.
# Word male not in the Embedding.
# Word meets not in the Embedding.
# Word plus not in the Embedding.
# Word hands not in the Embedding.
# Word interested not in the Embedding.
# Word beauty not in the Embedding.
# Word features not in the Embedding.
# Word street not in the Embedding.
# Word perfectly not in the Embedding.
# Word laughs not in the Embedding.
# Word stage not in the Embedding.
# Word nature not in the Embedding.
# Word effect not in the Embedding.
# Word comment not in the Embedding.
# Word forward not in the Embedding.
# Word nor not in the Embedding.
# Word previous not in the Embedding.
# Word badly not in the Embedding.
# Word sounds not in the Embedding.
# Word japanese not in the Embedding.
# Word weird not in the Embedding.
# Word island not in the Embedding.
# Word inside not in the Embedding.
# Word personal not in the Embedding.
# Word quickly not in the Embedding.
# Word total not in the Embedding.
# Word keeps not in the Embedding.
# Word towards not in the Embedding.
# Word america not in the Embedding.
# Word result not in the Embedding.
# Word battle not in the Embedding.
# Word crazy not in the Embedding.
# Word worked not in the Embedding.
# Word setting not in the Embedding.
# Word earlier not in the Embedding.
# Word background not in the Embedding.
# Word mess not in the Embedding.
# Word cop not in the Embedding.
# Word fire not in the Embedding.
# Word copy not in the Embedding.
# Word realize not in the Embedding.
# Word unique not in the Embedding.
# Word dumb not in the Embedding.
# Word powerful not in the Embedding.
# Word lee not in the Embedding.
# Word mark not in the Embedding.
# Word business not in the Embedding.
# Word rate not in the Embedding.
# Word older not in the Embedding.
# Word dramatic not in the Embedding.
# Word pay not in the Embedding.
# Word following not in the Embedding.
# Word joke not in the Embedding.
# Word girlfriend not in the Embedding.
# Word plenty not in the Embedding.
# Word creepy not in the Embedding.
# Word baby not in the Embedding.
# Word development not in the Embedding.
# Word appear not in the Embedding.
# Word brings not in the Embedding.
# Word front not in the Embedding.
# Word ask not in the Embedding.
# Word dream not in the Embedding.
# Word water not in the Embedding.
# Word bill not in the Embedding.
# Word admit not in the Embedding.
# Word rich not in the Embedding.
# Word apart not in the Embedding.
# Word joe not in the Embedding.
# Word political not in the Embedding.
# Word reasons not in the Embedding.
# Word leading not in the Embedding.
# Word spent not in the Embedding.
# Word telling not in the Embedding.
# Word cover not in the Embedding.
# Word outside not in the Embedding.
# Word present not in the Embedding.
# Word wasted not in the Embedding.
# Word fighting not in the Embedding.
# Word deserves not in the Embedding.
# Word fails not in the Embedding.
# Word gun not in the Embedding.
# Word era not in the Embedding.
# Word success not in the Embedding.
# Word break not in the Embedding.
# Word party not in the Embedding.
# Word meant not in the Embedding.
# Word list not in the Embedding.
# Word expecting not in the Embedding.
# Word william not in the Embedding.
# Word create not in the Embedding.
# Word ideas not in the Embedding.
# Word ended not in the Embedding.
# Word agree not in the Embedding.
# Word missing not in the Embedding.
# Word recently not in the Embedding.
# Word secret not in the Embedding.
# Word talented not in the Embedding.
# Word zombie not in the Embedding.
# Word twist not in the Embedding.
# Word match not in the Embedding.
# Word caught not in the Embedding.
# Word fantasy not in the Embedding.
# Word hardly not in the Embedding.
# Word cute not in the Embedding.
# Word german not in the Embedding.
# Word large not in the Embedding.
# Word odd not in the Embedding.
# Word return not in the Embedding.
# Word clever not in the Embedding.
# Word laughing not in the Embedding.
# Word co not in the Embedding.
# Word plain not in the Embedding.
# Word disney not in the Embedding.
# Word members not in the Embedding.
# Word escape not in the Embedding.
# Word office not in the Embedding.
# Word italian not in the Embedding.
# Word potential not in the Embedding.
# Word created not in the Embedding.
# Word missed not in the Embedding.
# Word flat not in the Embedding.
# Word pace not in the Embedding.
# Word wrote not in the Embedding.
# Word pure not in the Embedding.
# Word cartoon not in the Embedding.
# Word married not in the Embedding.
# Word waiting not in the Embedding.
# Word state not in the Embedding.
# Word century not in the Embedding.
# Word filled not in the Embedding.
# Word further not in the Embedding.
# Word incredible not in the Embedding.
# Word public not in the Embedding.
# Word mentioned not in the Embedding.
# Word cold not in the Embedding.
# Word sadly not in the Embedding.
# Word hold not in the Embedding.
# Word visual not in the Embedding.
# Word familiar not in the Embedding.
# Word slightly not in the Embedding.
# Word van not in the Embedding.
# Word considering not in the Embedding.
# Word science not in the Embedding.
# Word train not in the Embedding.
# Word died not in the Embedding.
# Word language not in the Embedding.
# Word speak not in the Embedding.
# Word popular not in the Embedding.
# Word store not in the Embedding.
# Word company not in the Embedding.
# Word uses not in the Embedding.
# Word sweet not in the Embedding.
# Word decides not in the Embedding.
# Word value not in the Embedding.
# Word sees not in the Embedding.
# Word anti not in the Embedding.
# Word credit not in the Embedding.
# Word social not in the Embedding.
# Word force not in the Embedding.
# Word bored not in the Embedding.
# Word dancing not in the Embedding.
# Word neither not in the Embedding.
# Word intelligent not in the Embedding.
# Word hair not in the Embedding.
# Word trouble not in the Embedding.
# Word follows not in the Embedding.
# Word compared not in the Embedding.
# Word choice not in the Embedding.
# Word la not in the Embedding.
# Word former not in the Embedding.
# Word common not in the Embedding.
# Word appreciate not in the Embedding.
# Word suddenly not in the Embedding.
# Word fit not in the Embedding.
# Word younger not in the Embedding.
# Word amount not in the Embedding.
# Word moves not in the Embedding.
# Word college not in the Embedding.
# Word mad not in the Embedding.
# Word brain not in the Embedding.
# Word alive not in the Embedding.
# Word biggest not in the Embedding.
# Word yeah not in the Embedding.
# Word fear not in the Embedding.
# Word images not in the Embedding.
# Word concept not in the Embedding.
# Word scott not in the Embedding.
# Word drug not in the Embedding.
# Word law not in the Embedding.
# Word post not in the Embedding.
# Word successful not in the Embedding.
# Word control not in the Embedding.
# Word situations not in the Embedding.
# Word exciting not in the Embedding.
# Word band not in the Embedding.
# Word project not in the Embedding.
# Word pointless not in the Embedding.
# Word cause not in the Embedding.
# Word longer not in the Embedding.
# Word pathetic not in the Embedding.
# Word focus not in the Embedding.
# Word spend not in the Embedding.
# Word christmas not in the Embedding.
# Word fake not in the Embedding.
# Word meaning not in the Embedding.
# Word sick not in the Embedding.
# Word culture not in the Embedding.
# Word positive not in the Embedding.
# Word trash not in the Embedding.
# Word kills not in the Embedding.
# Word revenge not in the Embedding.
# Word effective not in the Embedding.
# Word basic not in the Embedding.
# Word decide not in the Embedding.
# Word recent not in the Embedding.
# Word honest not in the Embedding.
# Word awesome not in the Embedding.
# Word respect not in the Embedding.
# Word adventure not in the Embedding.
# Word spirit not in the Embedding.
# Word consider not in the Embedding.
# Word alien not in the Embedding.
# Word brothers not in the Embedding.
# Word questions not in the Embedding.
# Word jane not in the Embedding.
# Word likes not in the Embedding.
# Word super not in the Embedding.
# Word aside not in the Embedding.
# Word barely not in the Embedding.
# Word pick not in the Embedding.
# Word changed not in the Embedding.
# Word singing not in the Embedding.
# Word impossible not in the Embedding.
# Word shoot not in the Embedding.
# Word solid not in the Embedding.
# Word walk not in the Embedding.
# Word studio not in the Embedding.
# Word master not in the Embedding.
# Word accent not in the Embedding.
# Word leaving not in the Embedding.
# Word showed not in the Embedding.
# Word cat not in the Embedding.
# Word channel not in the Embedding.
# Word gang not in the Embedding.
# Word blue not in the Embedding.
# Word runs not in the Embedding.
# Word prison not in the Embedding.
# Word genius not in the Embedding.
# Word shooting not in the Embedding.
# Word road not in the Embedding.
# Word literally not in the Embedding.
# Word failed not in the Embedding.
# Word vampire not in the Embedding.
# Word books not in the Embedding.
# Word chemistry not in the Embedding.
# Word somewhere not in the Embedding.
# Word immediately not in the Embedding.
# Word ben not in the Embedding.
# Word thanks not in the Embedding.
# Word ex not in the Embedding.
# Word tough not in the Embedding.
# Word bought not in the Embedding.
# Word camp not in the Embedding.
# Word touch not in the Embedding.
# Word considered not in the Embedding.
# Word honestly not in the Embedding.
# Word trip not in the Embedding.
# Word south not in the Embedding.
# Word fair not in the Embedding.
# Word grade not in the Embedding.
# Word week not in the Embedding.
# Word ability not in the Embedding.
# Word stick not in the Embedding.
# Word sitting not in the Embedding.
# Word adult not in the Embedding.
# Word win not in the Embedding.
# Word mood not in the Embedding.
# Word army not in the Embedding.
# Word added not in the Embedding.
# Word thinks not in the Embedding.
# Word glad not in the Embedding.
# Word explain not in the Embedding.
# Word west not in the Embedding.
# Word sexy not in the Embedding.
# Word bother not in the Embedding.
# Word tone not in the Embedding.
# Word journey not in the Embedding.
# Word issues not in the Embedding.
# Word normal not in the Embedding.
# Word bed not in the Embedding.
# Word charles not in the Embedding.
# Word personally not in the Embedding.
# Word standard not in the Embedding.
# Word jim not in the Embedding.
# Word heavy not in the Embedding.
# Word edge not in the Embedding.
# Word purpose not in the Embedding.
# Word nowhere not in the Embedding.
# Word won not in the Embedding.
# Word park not in the Embedding.
# Word chase not in the Embedding.
# Word pieces not in the Embedding.
# Word likely not in the Embedding.
# Word door not in the Embedding.
# Word taste not in the Embedding.
# Word nobody not in the Embedding.
# Word silent not in the Embedding.
# Word naked not in the Embedding.
# Word military not in the Embedding.
# Word sam not in the Embedding.
# Word mary not in the Embedding.
# Word available not in the Embedding.
# Word motion not in the Embedding.
# Word computer not in the Embedding.
# Word terms not in the Embedding.
# Word appearance not in the Embedding.
# Word smart not in the Embedding.
# Word frank not in the Embedding.
# Word catch not in the Embedding.
# Word photography not in the Embedding.
# Word soul not in the Embedding.
# Word bottom not in the Embedding.
# Word presence not in the Embedding.
# Word government not in the Embedding.
# Word ride not in the Embedding.
# Word opera not in the Embedding.
# Word date not in the Embedding.
# Word natural not in the Embedding.
# Word lovely not in the Embedding.
# Word pictures not in the Embedding.
# Word managed not in the Embedding.
# Word innocent not in the Embedding.
# Word loud not in the Embedding.
# Word wow not in the Embedding.
# Word changes not in the Embedding.
# Word drive not in the Embedding.
# Word constantly not in the Embedding.
# Word knowing not in the Embedding.
# Word magic not in the Embedding.
# Word walking not in the Embedding.
# Word emotions not in the Embedding.
# Word giant not in the Embedding.
# Word details not in the Embedding.
# Word boyfriend not in the Embedding.
# Word indian not in the Embedding.
# Word steve not in the Embedding.
# Word suppose not in the Embedding.
# Word pass not in the Embedding.
# Word track not in the Embedding.
# Word plan not in the Embedding.
# Word ed not in the Embedding.
# Word hey not in the Embedding.
# Word rare not in the Embedding.
# Word planet not in the Embedding.
# Word london not in the Embedding.
# Word ghost not in the Embedding.
# Word dad not in the Embedding.
# Word thank not in the Embedding.
# Word attack not in the Embedding.
# Word loves not in the Embedding.
# Word key not in the Embedding.
# Word throw not in the Embedding.
# Word unbelievable not in the Embedding.
# Word jones not in the Embedding.
# Word touching not in the Embedding.
# Word places not in the Embedding.
# Word names not in the Embedding.
# Word besides not in the Embedding.
# Word ray not in the Embedding.
# Word award not in the Embedding.
# Word slowly not in the Embedding.
# Word chris not in the Embedding.
# Word building not in the Embedding.
# Word zombies not in the Embedding.
# Word painful not in the Embedding.
# Word land not in the Embedding.
# Word everybody not in the Embedding.
# Word teen not in the Embedding.
# Word wild not in the Embedding.
# Word excuse not in the Embedding.
# Word filming not in the Embedding.
# Word speaking not in the Embedding.
# Word stands not in the Embedding.
# Word bond not in the Embedding.
# Word finish not in the Embedding.
# Word club not in the Embedding.
# Word race not in the Embedding.
# Word feelings not in the Embedding.
# Word festival not in the Embedding.
# Word hoping not in the Embedding.
# Word puts not in the Embedding.
# Word fully not in the Embedding.
# Word acts not in the Embedding.
# Word central not in the Embedding.
# Word sub not in the Embedding.
# Word forever not in the Embedding.
# Word mistake not in the Embedding.
# Word surely not in the Embedding.
# Word green not in the Embedding.
# Word notice not in the Embedding.
# Word paris not in the Embedding.
# Word lived not in the Embedding.
# Word victim not in the Embedding.
# Word expectations not in the Embedding.
# Word emotion not in the Embedding.
# Word student not in the Embedding.
# Word stunning not in the Embedding.
# Word image not in the Embedding.
# Word tired not in the Embedding.
# Word double not in the Embedding.
# Word sent not in the Embedding.
# Word million not in the Embedding.
# Word bruce not in the Embedding.
# Word pain not in the Embedding.
# Word hurt not in the Embedding.
# Word cry not in the Embedding.
# Word justice not in the Embedding.
# Word charlie not in the Embedding.
# Word six not in the Embedding.
# Word born not in the Embedding.
# Word ahead not in the Embedding.
# Word support not in the Embedding.
# Word ship not in the Embedding.
# Word harry not in the Embedding.
# Word hospital not in the Embedding.
# Word opportunity not in the Embedding.
# Word fresh not in the Embedding.
# Word tony not in the Embedding.
# Word laughed not in the Embedding.
# Word offer not in the Embedding.
# Word color not in the Embedding.
# Word confusing not in the Embedding.
# Word smith not in the Embedding.
# Word faces not in the Embedding.
# Word random not in the Embedding.
# Word happening not in the Embedding.
# Word dreams not in the Embedding.
# Word news not in the Embedding.
# Word finding not in the Embedding.
# Word content not in the Embedding.
# Word location not in the Embedding.
# Word direct not in the Embedding.
# Word include not in the Embedding.
# Word students not in the Embedding.
# Word shock not in the Embedding.
# Word confused not in the Embedding.
# Word suggest not in the Embedding.
# Word jean not in the Embedding.
# Word held not in the Embedding.
# Word drugs not in the Embedding.
# Word folks not in the Embedding.
# Word marriage not in the Embedding.
# Word porn not in the Embedding.
# Word agent not in the Embedding.
# Word bar not in the Embedding.
# Word beat not in the Embedding.
# Word answer not in the Embedding.
# Word boss not in the Embedding.
# Word dies not in the Embedding.
# Word pull not in the Embedding.
# Word twice not in the Embedding.
# Word lover not in the Embedding.
# Word summer not in the Embedding.
# Word fell not in the Embedding.
# Word relationships not in the Embedding.
# Word putting not in the Embedding.
# Word difference not in the Embedding.
# Word spot not in the Embedding.
# Word ground not in the Embedding.
# Word billy not in the Embedding.
# Word cops not in the Embedding.
# Word ii not in the Embedding.
# Word impressed not in the Embedding.
# Word falling not in the Embedding.
# Word batman not in the Embedding.
# Word americans not in the Embedding.
# Word forgotten not in the Embedding.
# Word trailer not in the Embedding.
# Word martin not in the Embedding.
# Word collection not in the Embedding.
# Word paid not in the Embedding.
# Word information not in the Embedding.
# Word moral not in the Embedding.
# Word russian not in the Embedding.
# Word creative not in the Embedding.
# Word helps not in the Embedding.
# Word extreme not in the Embedding.
# Word radio not in the Embedding.
# Word machine not in the Embedding.
# Word share not in the Embedding.
# Word funniest not in the Embedding.
# Word ugly not in the Embedding.
# Word mix not in the Embedding.
# Word gorgeous not in the Embedding.
# Word industry not in the Embedding.
# Word anymore not in the Embedding.
# Word wall not in the Embedding.
# Word wondering not in the Embedding.
# Word christian not in the Embedding.
# Word plane not in the Embedding.
# Word therefore not in the Embedding.
# Word suicide not in the Embedding.
# Word victims not in the Embedding.
# Word quick not in the Embedding.
# Word intense not in the Embedding.
# Word led not in the Embedding.
# Word followed not in the Embedding.
# Word event not in the Embedding.
# Word pop not in the Embedding.
# Word system not in the Embedding.
# Word step not in the Embedding.
# Word rip not in the Embedding.
# Word count not in the Embedding.
# Word stuck not in the Embedding.
# Word offers not in the Embedding.
# Word lets not in the Embedding.
# Word numbers not in the Embedding.
# Word allowed not in the Embedding.
# Word phone not in the Embedding.
# Word ms not in the Embedding.
# Word vs not in the Embedding.
# Word church not in the Embedding.
# Word stewart not in the Embedding.
# Word seven not in the Embedding.
# Word fashion not in the Embedding.
# Word attractive not in the Embedding.
# Word station not in the Embedding.
# Word hotel not in the Embedding.
# Word absolute not in the Embedding.
# Word ready not in the Embedding.
# Word negative not in the Embedding.
# Word becoming not in the Embedding.
# Word don not in the Embedding.
# Word animals not in the Embedding.
# Word impact not in the Embedding.
# Word area not in the Embedding.
# Word thats not in the Embedding.
# Word extra not in the Embedding.
# Word damn not in the Embedding.
# Word inspired not in the Embedding.
# Word mom not in the Embedding.
# Word shocking not in the Embedding.
# Word standards not in the Embedding.
# Word onto not in the Embedding.
# Word personality not in the Embedding.
# Word turning not in the Embedding.
# Word woods not in the Embedding.
# Word wearing not in the Embedding.
# Word games not in the Embedding.
# Word grace not in the Embedding.
# Word seconds not in the Embedding.
# Word fellow not in the Embedding.
# Word captain not in the Embedding.
# Word picked not in the Embedding.
# Word wise not in the Embedding.
# Word dirty not in the Embedding.
# Word angry not in the Embedding.
# Word epic not in the Embedding.
# Word compare not in the Embedding.
# Word cross not in the Embedding.
# Word lies not in the Embedding.
# Word helped not in the Embedding.
# Word returns not in the Embedding.
# Word accident not in the Embedding.
# Word nasty not in the Embedding.
# Word thin not in the Embedding.
# Word actions not in the Embedding.
# Word listen not in the Embedding.
# Word sea not in the Embedding.
# Word professional not in the Embedding.
# Word flying not in the Embedding.
# Word kevin not in the Embedding.
# Word moved not in the Embedding.
# Word lose not in the Embedding.
# Word states not in the Embedding.
# Word passion not in the Embedding.
# Word childhood not in the Embedding.
# Word process not in the Embedding.
# Word member not in the Embedding.
# Word teenage not in the Embedding.
# Word zero not in the Embedding.
# Word mouth not in the Embedding.
# Word theatre not in the Embedding.
# Word teacher not in the Embedding.
# Word afraid not in the Embedding.
# Word jason not in the Embedding.
# Word search not in the Embedding.
# Word carry not in the Embedding.
# Word sleep not in the Embedding.
# Word kelly not in the Embedding.
# Word gold not in the Embedding.
# Word continue not in the Embedding.
# Word apartment not in the Embedding.
# Word food not in the Embedding.
# Word horse not in the Embedding.
# Word sight not in the Embedding.
# Word realized not in the Embedding.
# Word asked not in the Embedding.
# Word wanting not in the Embedding.
# Word rape not in the Embedding.
# Word pleasure not in the Embedding.
# Word dying not in the Embedding.
# Word thomas not in the Embedding.
# Word provide not in the Embedding.
# Word clothes not in the Embedding.
# Word willing not in the Embedding.
# Word sucks not in the Embedding.
# Word queen not in the Embedding.
# Word memory not in the Embedding.
# ...
# Word papi not in the Embedding.
# Word ler not in the Embedding.
# Word upload not in the Embedding.
# Word tawa not in the Embedding.
# Word cupcake not in the Embedding.
# Word amiga not in the Embedding.
# Word ropa not in the Embedding.
# Word jk not in the Embedding.
# Word grammys not in the Embedding.
# Word oye not in the Embedding.
# Word meia not in the Embedding.
# Word amo not in the Embedding.
# Word tarik not in the Embedding.
# Word peso not in the Embedding.
# Word gd not in the Embedding.
# Word noch not in the Embedding.
# Word pone not in the Embedding.
# Word ejemplo not in the Embedding.
# Word pensaba not in the Embedding.
# Word cuatro not in the Embedding.
# Word pendejo not in the Embedding.
# Word ati not in the Embedding.
# Word boludo not in the Embedding.
# Word maar not in the Embedding.
# Word londres not in the Embedding.
# Word dal not in the Embedding.
# Word feelin not in the Embedding.
# Word ultimo not in the Embedding.
# Word ele not in the Embedding.
# Word sn not in the Embedding.
# Word beter not in the Embedding.
# Word lalala not in the Embedding.
# Word stp not in the Embedding.
# Word pueblo not in the Embedding.
# Word vino not in the Embedding.
# Word pide not in the Embedding.
# Word jogando not in the Embedding.
# Word dok not in the Embedding.
# Word luego not in the Embedding.
# Word iglesia not in the Embedding.
# Word pelicula not in the Embedding.
# Word saat not in the Embedding.
# Word stfu not in the Embedding.
# Word hei not in the Embedding.
# Word paramore not in the Embedding.
# Word comigo not in the Embedding.
# Word mong not in the Embedding.
# Word att not in the Embedding.
# Word nueva not in the Embedding.
# Word obra not in the Embedding.
# Word ara not in the Embedding.
# Word bueno not in the Embedding.
# Word df not in the Embedding.
# Word td not in the Embedding.
# Word ight not in the Embedding.
# Word playlist not in the Embedding.
# Word madres not in the Embedding.
# Word parti not in the Embedding.
# Word tek not in the Embedding.
# Word pissed not in the Embedding.
# Word estrella not in the Embedding.
# Word estados not in the Embedding.
# Word unidos not in the Embedding.
# Word nahh not in the Embedding.
# Word probs not in the Embedding.
# Word patria not in the Embedding.
# Word vai not in the Embedding.
# Word coldplay not in the Embedding.
# Word asi not in the Embedding.
# Word camino not in the Embedding.
# Word cl not in the Embedding.
# Word kaya not in the Embedding.
# Word mec not in the Embedding.
# Word sorriso not in the Embedding.
# Word anda not in the Embedding.
# Word teamo not in the Embedding.
# Word juni not in the Embedding.
# Word nuevo not in the Embedding.
# Word muito not in the Embedding.
# Word muita not in the Embedding.
# Word mana not in the Embedding.
# Word alli not in the Embedding.
# Word wie not in the Embedding.
# Word playa not in the Embedding.
# Word poco not in the Embedding.
# Word mlb not in the Embedding.
# Word historia not in the Embedding.
# Word grandes not in the Embedding.
# Word goodluck not in the Embedding.
# Word minas not in the Embedding.
# Word lulus not in the Embedding.
# Word gan not in the Embedding.
# Word regarde not in the Embedding.
# Word sino not in the Embedding.
# Word marca not in the Embedding.
# Word familia not in the Embedding.
# Word senin not in the Embedding.
# Word gaza not in the Embedding.
# Word perra not in the Embedding.
# Word homie not in the Embedding.
# Word perfeita not in the Embedding.
# Word cosa not in the Embedding.
# Word pts not in the Embedding.
# Word maka not in the Embedding.
# Word enquanto not in the Embedding.
# Word ela not in the Embedding.
# Word fora not in the Embedding.
# Word eres not in the Embedding.
# Word dese not in the Embedding.
# Word abi not in the Embedding.
# Word palavras not in the Embedding.
# Word nung not in the Embedding.
# Word sel not in the Embedding.
# Word galo not in the Embedding.
# Word gif not in the Embedding.
# Word qe not in the Embedding.
# Word tdk not in the Embedding.
# Word kaos not in the Embedding.
# Word tk not in the Embedding.
# Word numa not in the Embedding.
# Word flor not in the Embedding.
# Word mee not in the Embedding.
# Word hhaha not in the Embedding.
# Word matar not in the Embedding.
# Word bn not in the Embedding.
# Word mna not in the Embedding.
# Word yoi not in the Embedding.
# Word enfin not in the Embedding.
# Word breve not in the Embedding.
# Word lebron not in the Embedding.
# Word okc not in the Embedding.
# Word secreto not in the Embedding.
# Word raro not in the Embedding.
# Word muda not in the Embedding.
# Word dll not in the Embedding.
# Word ponte not in the Embedding.
# Word hadi not in the Embedding.
# Word lha not in the Embedding.
# Word rumah not in the Embedding.
# Word dato not in the Embedding.
# Word imagina not in the Embedding.
# Word var not in the Embedding.
# Word tengo not in the Embedding.
# Word yey not in the Embedding.
# Word puta not in the Embedding.
# Word sayang not in the Embedding.
# Word corto not in the Embedding.
# Word kok not in the Embedding.
# Word cont not in the Embedding.
# Word tane not in the Embedding.
# Word mie not in the Embedding.
# Word eng not in the Embedding.
# Word banda not in the Embedding.
# Word unico not in the Embedding.
# Word gh not in the Embedding.
# Word pera not in the Embedding.
# Word ingles not in the Embedding.
# Word unas not in the Embedding.
# Word liga not in the Embedding.
# Word sabi not in the Embedding.
# Word nota not in the Embedding.
# Word bene not in the Embedding.
# Word toute not in the Embedding.
# Word oomf not in the Embedding.
# Word nme not in the Embedding.
# Word festa not in the Embedding.
# Word kantor not in the Embedding.
# Word ml not in the Embedding.
# Word pura not in the Embedding.
# Word dinero not in the Embedding.
# Word moins not in the Embedding.
# Word pon not in the Embedding.
# Word nossa not in the Embedding.
# Word dur not in the Embedding.
# Word manda not in the Embedding.
# Word mulher not in the Embedding.
# Word certo not in the Embedding.
# Word ponto not in the Embedding.
# Word hier not in the Embedding.
# Word peka not in the Embedding.
# Word ojo not in the Embedding.
# Word hj not in the Embedding.
# Word trop not in the Embedding.
# Word killin not in the Embedding.
# Word lls not in the Embedding.
# Word hola not in the Embedding.
# Word leve not in the Embedding.
# Word ciudad not in the Embedding.
# Word lolol not in the Embedding.
# Word louco not in the Embedding.
# Word elas not in the Embedding.
# Word abrazo not in the Embedding.
# Word partido not in the Embedding.
# Word esperando not in the Embedding.
# Word compte not in the Embedding.
# Word mola not in the Embedding.
# Word saiba not in the Embedding.
# Word chrome not in the Embedding.
# Word despertar not in the Embedding.
# Word tryin not in the Embedding.
# Word calles not in the Embedding.
# Word ama not in the Embedding.
# Word aussi not in the Embedding.
# Word solamente not in the Embedding.
# Word vez not in the Embedding.
# Word pls not in the Embedding.
# Word rafa not in the Embedding.
# Word cadena not in the Embedding.
# Word nacional not in the Embedding.
# Word justicia not in the Embedding.
# Word admin not in the Embedding.
# Word mente not in the Embedding.
# Word sagittarius not in the Embedding.
# Word morrer not in the Embedding.
# Word xl not in the Embedding.
# Word casi not in the Embedding.
# Word hati not in the Embedding.
# Word dg not in the Embedding.
# Word workin not in the Embedding.
# Word doin not in the Embedding.
# Word hv not in the Embedding.
# Word esperanza not in the Embedding.
# Word parada not in the Embedding.
# Word cest not in the Embedding.
# Word baja not in the Embedding.
# Word tio not in the Embedding.
# Word sevilla not in the Embedding.
# Word hafta not in the Embedding.
# Word sempre not in the Embedding.
# Word playin not in the Embedding.
# Word cada not in the Embedding.
# Word eeh not in the Embedding.
# Word somos not in the Embedding.
# Word nadie not in the Embedding.
# Word batalla not in the Embedding.
# Word muka not in the Embedding.
# Word okok not in the Embedding.
# Word dices not in the Embedding.
# Word trending not in the Embedding.
# Word nok not in the Embedding.
# Word comi not in the Embedding.
# Word fait not in the Embedding.
# Word pedo not in the Embedding.
# Word autres not in the Embedding.
# Word fone not in the Embedding.
# Word sz not in the Embedding.
# Word biarkan not in the Embedding.
# Word bintang not in the Embedding.
# Word bbm not in the Embedding.
# Word mam not in the Embedding.
# Word piso not in the Embedding.
# Word fotos not in the Embedding.
# Word nis not in the Embedding.
# Word loe not in the Embedding.
# Word ffs not in the Embedding.
# Word bref not in the Embedding.
# Word peu not in the Embedding.
# Word adidas not in the Embedding.
# Word lowkey not in the Embedding.
# Word pinches not in the Embedding.
# Word nikah not in the Embedding.
# Word iy not in the Embedding.
# Word espera not in the Embedding.
# Word tropa not in the Embedding.
# Word mirada not in the Embedding.
# Word jst not in the Embedding.
# Word bil not in the Embedding.
# Word exo not in the Embedding.
# Word clases not in the Embedding.
# Word tweet not in the Embedding.
# Word weg not in the Embedding.
# Word dito not in the Embedding.
# Word parte not in the Embedding.
# Word kau not in the Embedding.
# Word tuo not in the Embedding.
# Word gente not in the Embedding.
# Word ot not in the Embedding.
# Word hahahahah not in the Embedding.
# Word blanco not in the Embedding.
# Word hein not in the Embedding.
# Word nothin not in the Embedding.
# Word desde not in the Embedding.
# Word votre not in the Embedding.
# Word vos not in the Embedding.
# Word mh not in the Embedding.
# Word teatro not in the Embedding.
# Word sto not in the Embedding.
# Word lmfao not in the Embedding.
# Word amando not in the Embedding.
# Word goin not in the Embedding.
# Word rola not in the Embedding.
# Word nvm not in the Embedding.
# Word aver not in the Embedding.
# Word js not in the Embedding.
# Word pk not in the Embedding.
# Word bir not in the Embedding.
# Word vcs not in the Embedding.
# Word algo not in the Embedding.
# Word ataque not in the Embedding.
# Word gordo not in the Embedding.
# Word ksa not in the Embedding.
# Word dela not in the Embedding.
# Word papel not in the Embedding.
# Word hora not in the Embedding.
# Word perf not in the Embedding.
# Word thrones not in the Embedding.
# Word pq not in the Embedding.
# Word chibi not in the Embedding.
# Word kayak not in the Embedding.
# Word ves not in the Embedding.
# Word ile not in the Embedding.
# Word arti not in the Embedding.
# Word wel not in the Embedding.
# Word siempre not in the Embedding.
# Word ato not in the Embedding.
# Word tmn not in the Embedding.
# Word pau not in the Embedding.
# Word lololol not in the Embedding.
# Word hahahahahahahaha not in the Embedding.
# Word agua not in the Embedding.
# Word padres not in the Embedding.
# Word bos not in the Embedding.
# Word thn not in the Embedding.
# Word caca not in the Embedding.
# Word nou not in the Embedding.
# Word mundial not in the Embedding.
# Word livro not in the Embedding.
# Word java not in the Embedding.
# Word mentiras not in the Embedding.
# Word voor not in the Embedding.
# Word fui not in the Embedding.
# Word humano not in the Embedding.
# Word fam not in the Embedding.
# Word ahah not in the Embedding.
# Word jullie not in the Embedding.
# Word salve not in the Embedding.
# Word niggaz not in the Embedding.
# Word gata not in the Embedding.
# Word voce not in the Embedding.
# Word cst not in the Embedding.
# Word vergonha not in the Embedding.
# Word lagrimas not in the Embedding.
# Word unica not in the Embedding.
# Word bien not in the Embedding.
# Word dios not in the Embedding.
# Word melhores not in the Embedding.
# Word vidas not in the Embedding.
# Word animales not in the Embedding.
# Word muere not in the Embedding.
# Word yakin not in the Embedding.
# Word hhe not in the Embedding.
# Word maha not in the Embedding.
# Word bora not in the Embedding.
# Word kah not in the Embedding.
# Word ntr not in the Embedding.
# Word knicks not in the Embedding.
# Word muerte not in the Embedding.
# Word tua not in the Embedding.
# Word ont not in the Embedding.
# Word abt not in the Embedding.
# Word chau not in the Embedding.
# Word ley not in the Embedding.
# Word bajo not in the Embedding.
# Word tiene not in the Embedding.
# Word quien not in the Embedding.
# Word wenn not in the Embedding.
# Word socorro not in the Embedding.
# Word imagen not in the Embedding.
# Word mf not in the Embedding.
# Word heyy not in the Embedding.
# Word veel not in the Embedding.
# Word corpo not in the Embedding.
# Word tommorow not in the Embedding.
# Word nessa not in the Embedding.
# Word sista not in the Embedding.
# Word taurus not in the Embedding.
# Word aduh not in the Embedding.
# Word lengua not in the Embedding.
# Word nh not in the Embedding.
# Word meme not in the Embedding.
# Word peur not in the Embedding.
# Word filho not in the Embedding.
# Word muerto not in the Embedding.
# Word hermoso not in the Embedding.
# Word ultima not in the Embedding.
# Word tsk not in the Embedding.
# Word rakuten not in the Embedding.
# Word bsa not in the Embedding.
# Word welp not in the Embedding.
# Word ahahahah not in the Embedding.
# Word leven not in the Embedding.
# Word oke not in the Embedding.
# Word tht not in the Embedding.
# Word kush not in the Embedding.
# Word lh not in the Embedding.
# Word duda not in the Embedding.
# Word levar not in the Embedding.
# Word onde not in the Embedding.
# Word minta not in the Embedding.
# Word kw not in the Embedding.
# Word buen not in the Embedding.
# Word trabajo not in the Embedding.
# Word lento not in the Embedding.
# Word boas not in the Embedding.
# Word pasar not in the Embedding.
# Word asco not in the Embedding.
# Word dentro not in the Embedding.
# Word busco not in the Embedding.
# Word vivir not in the Embedding.
# Word meilleur not in the Embedding.
# Word tren not in the Embedding.
# Word bem not in the Embedding.
# Word klu not in the Embedding.
# Word cupcakes not in the Embedding.
# Word nigga not in the Embedding.
# Word banco not in the Embedding.
# Word jah not in the Embedding.
# Word ns not in the Embedding.
# Word usb not in the Embedding.
# Word puede not in the Embedding.
# Word ser not in the Embedding.
# Word gs not in the Embedding.
# Word sul not in the Embedding.
# Word suis not in the Embedding.
# Word wks not in the Embedding.
# Word boong not in the Embedding.
# Word mim not in the Embedding.
# Word zo not in the Embedding.
# Word ev not in the Embedding.
# Word bunga not in the Embedding.
# Word bae not in the Embedding.
# Word dejas not in the Embedding.
# Word quase not in the Embedding.
# Word haz not in the Embedding.
# Word doce not in the Embedding.
# Word niks not in the Embedding.
# Word gros not in the Embedding.
# Word vivo not in the Embedding.
# Word voy not in the Embedding.
# Word toujours not in the Embedding.
# Word artis not in the Embedding.
# Word paro not in the Embedding.
# Word fucking not in the Embedding.
# Word mang not in the Embedding.
# Word nad not in the Embedding.
# Word diye not in the Embedding.
# Word ein not in the Embedding.
# Word toda not in the Embedding.
# Word mobil not in the Embedding.
# Word seo not in the Embedding.
# Word kann not in the Embedding.
# Word culpa not in the Embedding.
# Word lado not in the Embedding.
# Word bff not in the Embedding.
# Word kt not in the Embedding.
# Word tomo not in the Embedding.
# Word salir not in the Embedding.
# Word globo not in the Embedding.
# Word bayern not in the Embedding.
# Word daar not in the Embedding.
# Word tanto not in the Embedding.
# Word samsung not in the Embedding.
# Word haber not in the Embedding.
# Word iu not in the Embedding.
# Word koq not in the Embedding.
# Word hehehehe not in the Embedding.
# Word nunca not in the Embedding.
# Word pasa not in the Embedding.
# Word vraiment not in the Embedding.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a9fcbb99cb35> in <module>
# ----> 1 results = compare_embeddings(datasets_and_dicts, embeddings_dict, parameters_dict)
#
# <ipython-input-59-63f06a498436> in compare_embeddings(datasets, embeddings, params, number_of_models)
#      29         for j in range(0, 6):
#      30
# ---> 31             keras_model = Keras_Model(params)
#      32             keras_model.model.layers[0].set_weights([emb_matrix])
#      33             keras_model.model.layers[0].trainable = keras_model.model.layers[1].trainable = False
#
# NameError: name 'Keras_Model' is not defined
